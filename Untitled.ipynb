# %%
import pandas as pd
import re
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("SMCA_CHIH_2015_2018.csv",
                parse_dates=['Fecha'])
df.head(100)
# Out:
#    CONTAMINANTE      Fecha  HORA CHIH-CEN CHIH-SUR
# 0            CO 2015-01-20    17               0.6
# 1            CO 2015-01-20    18               0.5
# 2            CO 2015-01-20    19               0.8
# 3            CO 2015-01-20    20               1.7
# 4            CO 2015-01-20    21               1.4
# ..          ...        ...   ...      ...      ...
# 95           CO 2015-01-24    18               0.4
# 96           CO 2015-01-24    19               0.5
# 97           CO 2015-01-24    20               0.6
# 98           CO 2015-01-24    21               0.9
# 99           CO 2015-01-24    22                 1
#
# [100 rows x 5 columns]

# %%
df.columns.values
# Out:
# array(['CONTAMINANTE', 'HORA', 'CHIH-CEN', 'CHIH-SUR'], dtype=object)

# %%
df.dtypes
# Out:
# CONTAMINANTE    object
# HORA             int64
# CHIH-CEN        object
# CHIH-SUR        object
# dtype: object

# %%
regex = r'(\d+\.\d{1,2})|[\d]'
df['CHIH-SUR'] = df['CHIH-SUR'].str.extract(regex, expand=False)

# %%
df['CHIH-SUR'] = pd.to_numeric(df['CHIH-SUR'])

# %%
df.shape
# Out:
# (161205, 5)

# %%
df.head(100)
# Out:
#    CONTAMINANTE      Fecha  HORA CHIH-CEN  CHIH-SUR
# 0            CO 2015-01-20    17                0.6
# 1            CO 2015-01-20    18                0.5
# 2            CO 2015-01-20    19                0.8
# 3            CO 2015-01-20    20                1.7
# 4            CO 2015-01-20    21                1.4
# ..          ...        ...   ...      ...       ...
# 95           CO 2015-01-24    18                0.4
# 96           CO 2015-01-24    19                0.5
# 97           CO 2015-01-24    20                0.6
# 98           CO 2015-01-24    21                0.9
# 99           CO 2015-01-24    22                NaN
#
# [100 rows x 5 columns]

# %%
df['CHIH-SUR'] = df['CHIH-SUR'].fillna(1)
df.head(100)
# Out:
#    CONTAMINANTE      Fecha  HORA CHIH-CEN  CHIH-SUR
# 0            CO 2015-01-20    17                0.6
# 1            CO 2015-01-20    18                0.5
# 2            CO 2015-01-20    19                0.8
# 3            CO 2015-01-20    20                1.7
# 4            CO 2015-01-20    21                1.4
# ..          ...        ...   ...      ...       ...
# 95           CO 2015-01-24    18                0.4
# 96           CO 2015-01-24    19                0.5
# 97           CO 2015-01-24    20                0.6
# 98           CO 2015-01-24    21                0.9
# 99           CO 2015-01-24    22                1.0
#
# [100 rows x 5 columns]

# %%
#df = df.groupby([df['Fecha']], as_index=False).mean()
#df.head(100)
# Out:
#         Fecha       HORA
# 0  2015-01-01  12.500000
# 1  2015-01-02  12.500000
# 2  2015-01-03  12.500000
# 3  2015-01-04  12.500000
# 4  2015-01-05  13.000000
# ..        ...        ...
# 95 2015-04-06  11.530120
# 96 2015-04-07  12.634409
# 97 2015-04-08  12.500000
# 98 2015-04-09  12.500000
# 99 2015-04-10  12.500000
#
# [100 rows x 2 columns]

# %%
df.drop(['HORA'], axis=1, inplace=True)
df_group = (df.groupby(['Fecha']).mean())

df_group
# Out:
#             CHIH-SUR
# Fecha
# 2015-01-01  1.000000
# 2015-01-02  0.910417
# 2015-01-03  0.856250
# 2015-01-04  0.942708
# 2015-01-05  0.926087
# ...              ...
# 2018-12-27  1.000000
# 2018-12-28  1.000000
# 2018-12-29  1.000000
# 2018-12-30  1.000000
# 2018-12-31  1.000000
#
# [1431 rows x 1 columns]

# %%
import matplotlib.pyplot
import matplotlib.dates
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from matplotlib.dates import DateFormatter
from datetime import datetime, timedelta

y_values = df['CHIH-SUR']
fig, ax = plt.subplots(figsize=(12, 8))
ax.plot(df_group,
        y_values.values,
       color='red')
ax.set(xlabel="Date", ylabel="Accumulated Contaminants",
      title="Contamimant progression throughout the years")

#format the x 

ax.xaxis.set_major_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(DateFormatter("%y-%m"))

#format the y axis

ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

plt.show()
# Out:
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
# Locator attempting to generate 1138 ticks ([-52.0, ..., 1085.0]), which exceeds Locator.MAXTICKS (1000).
