# %%
import pandas as pd
import re
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("SMCA_CHIH_2015_2018.csv")
df.head(100)
# Out:
#    CONTAMINANTE       Fecha  HORA CHIH-CEN CHIH-SUR
# 0            CO  20/01/2015    17               0.6
# 1            CO  20/01/2015    18               0.5
# 2            CO  20/01/2015    19               0.8
# 3            CO  20/01/2015    20               1.7
# 4            CO  20/01/2015    21               1.4
# ..          ...         ...   ...      ...      ...
# 95           CO  24/01/2015    18               0.4
# 96           CO  24/01/2015    19               0.5
# 97           CO  24/01/2015    20               0.6
# 98           CO  24/01/2015    21               0.9
# 99           CO  24/01/2015    22                 1
#
# [100 rows x 5 columns]

# %%
df.columns.values
# Out:
# array(['CONTAMINANTE', 'Fecha', 'HORA', 'CHIH-CEN', 'CHIH-SUR'],
#       dtype=object)

# %%
df.dtypes
# Out:
# CONTAMINANTE    object
# Fecha           object
# HORA             int64
# CHIH-CEN        object
# CHIH-SUR        object
# dtype: object

# %%
regex = r'(\d+\.\d{1,2})|[\d]'
df['CHIH-SUR'] = df['CHIH-SUR'].str.extract(regex, expand=False)

# %%
df['CHIH-SUR'] = pd.to_numeric(df['CHIH-SUR'])

# %%
df.shape
# Out:
# (161205, 5)

# %%
df.head(100)
# Out:
#    CONTAMINANTE       Fecha  HORA CHIH-CEN  CHIH-SUR
# 0            CO  20/01/2015    17                0.6
# 1            CO  20/01/2015    18                0.5
# 2            CO  20/01/2015    19                0.8
# 3            CO  20/01/2015    20                1.7
# 4            CO  20/01/2015    21                1.4
# ..          ...         ...   ...      ...       ...
# 95           CO  24/01/2015    18                0.4
# 96           CO  24/01/2015    19                0.5
# 97           CO  24/01/2015    20                0.6
# 98           CO  24/01/2015    21                0.9
# 99           CO  24/01/2015    22                NaN
#
# [100 rows x 5 columns]

# %%
df['CHIH-SUR'] = df['CHIH-SUR'].fillna(0)
df.head(100)
# Out:
#    CONTAMINANTE       Fecha  HORA CHIH-CEN  CHIH-SUR
# 0            CO  20/01/2015    17                0.6
# 1            CO  20/01/2015    18                0.5
# 2            CO  20/01/2015    19                0.8
# 3            CO  20/01/2015    20                1.7
# 4            CO  20/01/2015    21                1.4
# ..          ...         ...   ...      ...       ...
# 95           CO  24/01/2015    18                0.4
# 96           CO  24/01/2015    19                0.5
# 97           CO  24/01/2015    20                0.6
# 98           CO  24/01/2015    21                0.9
# 99           CO  24/01/2015    22                0.0
#
# [100 rows x 5 columns]

# %%
df = df.groupby([df['Fecha']]).mean()
df.head(100)
# Out:
#                  HORA  CHIH-SUR
# Fecha
# 01/01/2015  12.500000  0.000000
# 01/01/2016  12.500000  0.999167
# 01/01/2017  12.537815  1.872269
# 01/01/2018  12.531469  2.562937
# 01/02/2015  12.500000  0.160417
# ...               ...       ...
# 03/01/2016  12.500000  0.925833
# 03/01/2017  12.453782  4.894118
# 03/01/2018  12.545455  2.637762
# 03/02/2015  12.500000  0.165625
# 03/02/2016  12.500000  0.940000
#
# [100 rows x 2 columns]

# %%
import matplotlib.pyplot
import matplotlib.dates
from datetime import datetime, timedelta

dates = df['Fecha']

y_values = df['HORA']

plt.plot_date(dates, y_values)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib64/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fecha'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-99813ce1401e> in <module>
#       3 from datetime import datetime, timedelta
#       4
# ----> 5 dates = df['Fecha']
#       6
#       7 y_values = df['HORA']
#
# /usr/lib64/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /usr/lib64/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
# -> 3083                 raise KeyError(key) from err
#    3084
#    3085         if tolerance is not None:
#
# KeyError: 'Fecha'
